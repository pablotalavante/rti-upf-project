# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('./Logs/RTI_Class_headings_Aldo_35_M_1.csv')
df_find = df[df.progress == 0]
df_back = df[df.progress == 1]

# %%
df_find.plot(x='x', y='z')
#plt.xlim(-250, 250)
#plt.ylim(-100, 300)
# Out:
# <AxesSubplot:xlabel='x'>

# %%
df_back.plot(x='x', y='z', color='orange')
#plt.xlim(-250, 250)
#plt.ylim(-100, 300)
# Out:
# <AxesSubplot:xlabel='x'>
